# %% [markdown]
# ### Import Libraries ###

# %%
import numpy as np 
import pandas as pd 
from google.cloud import bigquery
from pandas.io import gbq

# %%
client = bigquery.Client()

# %%
query_= """
SELECT
--Selecting all columns
  * 
FROM
--You can select any day or month you want, the data will be the same because Google analytics collects data based on the same features
  `bigquery-public-data.google_analytics_sample.ga_sessions_*`
  """

# %%
safe_query_job= client.query(query_)
summary_df= safe_query_job.to_dataframe()
summary_df
# Out:
# SELECT
# --Selecting all columns
#   *
# FROM
# --You can select any day or month you want, the data will be the same because Google analytics collects data based on the same features
#   `bigquery-public-data.google_analytics_sample.ga_sessions_20170801`
# LIMIT
#   10

# %%
my_data = gbq.read_gbq(query_, project_id = 'my-project-97639')
# Out:
# Downloading: 100%|██████████| 903653/903653 [2:39:06<00:00, 94.66rows/s]

# %%
my_data.to_csv('google.csv')

# %%
display(my_data)
# Out:
#   visitorId  visitNumber     visitId  visitStartTime      date  \
# 0      None            1  1471870244      1471870244  20160822
# 1      None            1  1471934904      1471934904  20160822
# 2      None            1  1471851708      1471851708  20160822
# 3      None            1  1471853880      1471853880  20160822
# 4      None            1  1471860794      1471860794  20160822
# 5      None            1  1471917433      1471917433  20160822
# 6      None            1  1471902960      1471902960  20160822
# 7      None            1  1471900624      1471900624  20160822
# 8      None            1  1471856718      1471856718  20160822
# 9      None            1  1471860217      1471860217  20160822
#
#                                               totals  \
# 0  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 1  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 2  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# 3  {'visits': 1, 'hits': 1, 'pageviews': 1, 'time...
# ...
